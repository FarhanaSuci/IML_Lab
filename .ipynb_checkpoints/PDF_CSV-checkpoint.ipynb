# %%
import pdfplumber
import pandas as pd
import re

def extract_text_from_pdf(pdf_path):
    data = []
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text = page.extract_text()
            if text:
                lines = text.split("\n")
                data.extend(lines)
    return data

def clean_and_structure_data(data):
    structured_data = []
    temp_row = []
    for line in data:
        if re.match(r'^\s*$', line):  # Skip empty lines
            continue
        if is_new_record(line):  # Check if a new record starts
            if temp_row:
                structured_data.append(temp_row)
            temp_row = [line]
        else:
            temp_row.append(line)  # Append to the previous record
    
    if temp_row:  # Add last record
        structured_data.append(temp_row)
    
    return structured_data

def is_new_record(line):
    # Adjust this condition based on how new categories are identified in your PDF
    return bool(re.match(r'^[A-Z]+', line))  # Example: Categories start with uppercase letters

def save_to_csv(data, output_csv):
    df = pd.DataFrame(data)
    df.to_csv(output_csv, index=False, header=False)

# Jupyter Notebook does not require __name__ == "__main__"
pdf_path = "input1.pdf"  # Change this to your PDF file path
output_csv = "output.csv"

raw_data = extract_text_from_pdf(pdf_path)
structured_data = clean_and_structure_data(raw_data)
save_to_csv(structured_data, output_csv)

# Display extracted text as a DataFrame in Jupyter Notebook
df = pd.DataFrame(structured_data)
df.head()  # Display first few records
# Out:
#                                                   0   \
# 0                Create a Facebook Ad in Seven Steps
# 1  Facebook ads are an efficient form of advertis...
# 2                                              View.
#
#                                                   1   \
# 0                                               None
# 1  targeting specific demographics and personal i...
# 2  4. Select the characteristics of your target a...
#
#                                                   2   \
# 0                                               None
# 1  about 20 minutes by following these seven simp...
# 2  • Choose Your Country, State/Province, City or...
#
#                                                   3   \
# 0                                               None
# 1  1. Navigate to the Facebook Ads Manager on you...
# 2          • Choose the target Age Range and Gender.
#
#                                                   4   \
# 0                                               None
# 1  • Consider your audience. Use your Planning wo...
# 2  • Choose the Interest or Categories of Interes...
#
#                                   5   \
# 0                               None
# 1  • Log into your Facebook account.
# 2                www.life-global.org
#
#                                               6   \
# 0                                           None
# 1  • Go to https://www.facebook.com/advertising/
# 2                          • Choose Connections.
#
#                                     7   \
# 0                                 None
# 1              • Click “Create an Ad.”
# 2  5. Set the budget for your campaign
#
#                                             8   \
# 0                                         None
# 1  2. Set up the purpose and outcome of the ad
# 2   • Set the Campaign, Pricing, and Schedule.
#
#                                                   9   ...  \
# 0                                               None  ...
# 1  • Decide whether you want the ad to promote yo...  ...
# 2                  • Set a budget for your campaign:  ...
#
#                                      16  \
# 0                                  None
# 1                     liking your page.
# 2  your credit card number for billing.
#
#                                                   17  \
# 0                                               None
# 1  • Choose “Like my Page” if you want the ad to ...
# 2                    7. Begin following the results!
#
#                                                   18  \
# 0                                               None
# 1  target audience as possible with the goal that...
# 2  • Once you’ve submitted the ad, you will be ta...
#
#                                              19  \
# 0                                          None
# 1                                    your page.
# 2  where you can track the progress of your ad.
#
#                                                   20  \
# 0                                               None
# 1  • Choose “Click on my ad or sponsored story” i...
# 2  • One of the best ways to learn what does and ...
#
#                                                   21  \
# 0                                               None
# 1                                        clicked on.
# 2  out a variety of ads and targeted populations....
#
#                                                   22  \
# 0                                               None
# 1  • Name your campaign. This name will appear as...
# 2  works, you’ll be able to create future ad camp...
#
#                                                   23  \
# 0                                               None
# 1  3. Create the ad by selecting an image and wri...
# 2                                www.life-global.org
#
#                                                   24  \
# 0                                               None
# 1  • Edit your ad’s appearance. Watch the preview...
# 2                                               None
#
#                                                   25
# 0                                               None
# 1  will change as you make changes to your ad. Ad...
# 2                                               None
#
# [3 rows x 26 columns]
