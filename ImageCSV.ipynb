# %%
import pytesseract
from PIL import Image
import csv
import pandas as pd

# Path to your image file
image_path = "AminulSirIMG.jpeg"
output_csv = "image_csv.csv"

# Convert image to text using Tesseract
def extract_text_from_image(image_path):
    img = Image.open(image_path)
    text = pytesseract.image_to_string(img, lang="ben+eng")  # Specify both Bengali (ben) and English (eng)
    return text

# Save extracted text to CSV
def save_text_to_csv(text, output_csv):
    with open(output_csv, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        # Split text by line and write each line to CSV
        for line in text.splitlines():
            writer.writerow([line])

# Main processing
text = extract_text_from_image(image_path)
save_text_to_csv(text, output_csv)

# Display extracted text
print("Extracted Text:\n")
print(text)

# Load CSV into Pandas DataFrame for better visualization
df = pd.read_csv(output_csv, header=None, names=["Extracted Text"])
df.head()  # Display first few lines
# Out:
# Extracted Text:
#
# Department of Computer Science & Engineering
#
#
#
#
#
#
#
#
# জগন্নাথ বিশ্ববিদ্যালয় Jagannath University
# ঢাকা-১১০০, বাংলাদেশ। Dhaka-1 100, Bangladesh.
# (ফোনঃ ৯৫১৫০৩৪ 9515034
# ই : 7 fajmu.ac.bd
#
# মেইল cse@inu.ac.bd Web: http://www.cse,jnu.ac.bd
# ওয়েব: fy .ese,jnu.ac.bd
#
#
#
# জগন্নাথ বিশ্ববিদ্যালয়, কম্পিউটার সায়েন্স এন্ড ইষ্ভিনিয়ারিং বিভাগে 10.9০. 0) ০915
# (Professional) Program-4 Summer-2024 (১৬-তম ব্যাচ) শিক্ষাবর্ষের ১ম
# সেমিস্টারের /১৫৬৫1০৩৫ 199191)950 11018801101193/510]) (0913-5109), ৬1110
# 2024 (১৫-তম ব্যাচ) শিক্ষাবর্ষের ২য় সেমিস্টারের [0101 170017৩1 & 101 (CSE-
# 5201) “4% Summer-2023 (১৪-তম ব্যাচ) শিক্ষাবর্ষের ৩য় সেমিস্টারের 901+01৩
# Quality Assuarance and Testing (CSE-5309) 7&1 পরীক্ষা অনিবার্ধ কারন:বশত
# আগামী ১৭-০১-২০২৫ তারিখের পরিবর্তে ৩১-০১-২০২৫ তারিখে অনুষ্ঠিত হবে।
#
# ০৫৮৪
# (অধ্যাপক ড. মো: জুলফিকার মাহমুদ)
# পরিচালক
# MSc. in CSE (Professional) Program
# বিভাগ
#
# কম্পিউটার সায়েন্স এন ইহ্ভিনিয়ারিং বিভা
# জগন্নাথ বিশ্ববিদ্যালয়, ঢাকা ।
#                                  Extracted Text
# 0  Department of Computer Science & Engineering
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4   জগন্নাথ বিশ্ববিদ্যালয় Jagannath University
